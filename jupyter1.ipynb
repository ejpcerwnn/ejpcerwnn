# %% [markdown]
# <span style="color:blue"> Essai PANDAS PYTHON </span>
#
# <span style="color:blue"> 26 MARS 2026 </span>

# %% [markdown]
# <span style="color:blue"> AFFICHER un DATA FRAME </span>

# %%
import pandas as pd

d = {'col1': [1, 2, 3, 4, 7], 'col2': [4, 5, 6, 9, 5], 'col3': [7, 8, 12, 1, 11]}

df = pd.DataFrame(data=d)

print(df)
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12
# 3     4     9     1
# 4     7     5    11

# %% [markdown]
# <span style="color:blue"> AFFICHAGE du nombre des COLONNES </span>

# %%
count_column = df.shape[1]
print(count_column)
# Out:
# 3

# %% [markdown]
# <span style="color:blue"> AFFICHAGE NOMBRE DE LIGNES du DATA FRAME </span>

# %%
count_row = df.shape[0]
print(count_row)
# Out:
# 5
